# %% [markdown]
# # **Exercise 4**

# %% [markdown]
# What is the output of the following program? Draw a stack diagram that shows the state of the program when it prints the result.

# %%
def recurse(n, s):
    if n == 0:
        print(s)
    else:
        recurse(n-1, n+s)

recurse(3, 0)
# Out:
# 6

# %% [markdown]
# ```
# recurse:
#     s --> 6
#     n --> 0
# ```

# %% [markdown]
# ### 1) What would happen if you called this function like this: recurse(-1, 0)?

# %%
recurse(-1, 0)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-2-6da4f5310c53> in <module>()
# ----> 1 recurse(-1, 0)
#
# <ipython-input-1-5478b1fc572a> in recurse(n, s)
#       3         print(s)
#       4     else:
# ----> 5         recurse(n-1, n+s)
#       6
#       7 recurse(3, 0)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-5478b1fc572a> in recurse(n, s)
#       3         print(s)
#       4     else:
# ----> 5         recurse(n-1, n+s)
#       6
#       7 recurse(3, 0)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %% [markdown]
# As n starts  < 0 the recursion will never reach base case and would run forever if not by the error preventing this.

# %% [markdown]
# ### 2) Write a docstring that explains everything someone would need to know in order to use this function (and nothing else).

# %% [markdown]
# ```
# ''' Shows how recursion works
# n is the number of times recursion runs
# s is the variable that interacts with the recursion'''
# ```

# %% [markdown]
# # **Exercise 5**

# %% [markdown]
# Read the following function and see if you can figure out what it does (see the examples in Chapter 4). Then run it and see if you got it right.
# ```
# def draw(t, length, n):
#     if n == 0:
#         return
#     angle = 50
#     t.fd(length*n)
#     t.lt(angle)
#     draw(t, length, n-1)
#     t.rt(2*angle)
#     draw(t, length, n-1)
#     t.lt(angle)
#     t.bk(length*n)
# ```

# %% [markdown]
# step 1:<br>
# Draws a length*n long line and turn left by 50º<br>
# repeat step 1 subtracting 1 from n<br>
# step 2:
# Turns right by 100º<br>
# Repeat step 1 subtracting 1 from n<br>
# repeat step 2 subtracting 1 from n
#
# Loops through steps 1 and 2 untill n is 0 then go back to initial point.
