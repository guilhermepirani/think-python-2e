# %% [markdown]
# # **6.1 Return Values**

# %% [markdown]
# ### As an exercise, write a compare function that takes two values, x and y, and returns 1 if x > y, 0 if x == y, and -1 if x < y.

# %%
def compare(x, y):
    if x > y:
        return 1
    if x < y:
        return -1
    else:
        return 0

# %%
compare(2, 1)
# Out:
# 1

# %%
compare(1, 2)
# Out:
# -1

# %%
compare(2, 2)
# Out:
# 0

# %% [markdown]
# # **6.2 Incremental Development**

# %% [markdown]
# ### As an exercise, use incremental development to write a function called hypotenuse that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments. Record each stage of the development process as you go.

# %%
def hypotenuse(cat_a, cat_b):
    return 0.0

hypotenuse(3, 4)
# Out:
# 0.0

# %%
def hypotenuse(cat_a, cat_b):
    a = cat_a ** 2
    b = cat_b ** 2
    print(a, b)
    return 0.0
    
hypotenuse(3, 4)
# Out:
# 9 16
# 0.0

# %%
import math

def hypotenuse(cat_a, cat_b):
    a = cat_a ** 2
    b = cat_b ** 2
    c = math.sqrt((a + b))
    print(a, b, c)
    return 0.0
    
hypotenuse(3, 4)
# Out:
# 9 16 5.0
# 0.0

# %%
import math

# Remove Scaffolding
def hypotenuse(cat_a, cat_b):
    a = cat_a ** 2
    b = cat_b ** 2
    c = math.sqrt((a + b))
    return c

hypotenuse(3, 4)
# Out:
# 5.0

# %%
import math

# Refactor
def hypotenuse(cat_a, cat_b):
    '''Return Hipot. given other sides'''
    return math.sqrt(((cat_a ** 2) + (cat_b ** 2)))

hypotenuse(3, 4)
# Out:
# 5.0

# %% [markdown]
# # **6.4  Boolean functions**

# %% [markdown]
# ### As an exercise, write a function is_between(x, y, z) that returns True if x ≤ y ≤ z or False otherwise.

# %%
def is_between(x, y, z):
    '''Chekcs if y is equal or between x and z'''
    if x <= y <= z:
        return True
    else:
        return False

# %%
is_between(1, 3, 2)
# Out:
# False

# %%
is_between(1, 2, 3)
# Out:
# True

# %%
is_between(1, 1, 1)
# Out:
# True

# %%
is_between(5, 3, 2)
# Out:
# False

# %%
is_between(10, 11, 2)
# Out:
# False
